# %% [markdown]
# <a href="https://colab.research.google.com/github/NateTre/physiology/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Testing** **Reaction** **Time**

# %% [markdown]
# Purpose:
# To find differences in reactions based on auditory and visual senses and compare how fast each are.

# %% [markdown]
# Methods:
# 1.	Go to humanbenchmark.com to test visual reflexes
# 2.	Test 10 times
# 3.	Write down times each time
# 4.	To test auditory reaction time go to https://playback.fm/audio-reaction-time
# 5.	Test 10 times
# 6.	Write down times each time
# 7.	Calculate average for each to find average reaction times

# %% [markdown]
# Results:

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# Discussion: Hardware could be a factor; display could be loaded a little slow and affect visual reaction and same for audio. Another hardware factor could be whether a touchpad or mouse is used, sometimes touchpads on the macbook are a little slower to use.

# %% [markdown]
# Conclusion: On average the brain processes visual information faster than it processes auditory information
